# %%
import random
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.8   # average arrival rate: mean number of enqueues made per unit time, [0.0, 1.0)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.xlabel("ρ")
plt.ylabel("μ[q(t)]")
plt.show()
# Out:
# Arrival Rate: 0.8
#
# Traffic Intensity: 0.9
# Average Queue Length: 2.0501002004008018
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 0.4512987012987013
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.1435897435897435
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 3.310107948969578
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 3.7644092219020173
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 2.4197098549274636
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 2.436619718309859
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 26.89108910891089
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 8.036402912232978
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 16.421048420968418
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.8   # average arrival rate: mean number of enqueues made per unit time, [0.0, 1.0)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.xlabel("ρ")
plt.ylabel("μ[q(t)]")
plt.show()
# Out:
# Arrival Rate: 0.8
#
# Traffic Intensity: 0.9
# Average Queue Length: 1.5390781563126252
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 0.4366883116883117
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.6423076923076922
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 2.196270853778214
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 4.910662824207493
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 2.6293146573286643
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 3.5963508322663253
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 5.148334833483348
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 13.38531082486599
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 11.532630652613053
# --------------------------------------------------

# %%
import random
import sys
import numpy as np
import matplotlib.pyplot as plt

# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.8   # average arrival rate: mean number of enqueues made per unit time, [0.0, 1.0)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.xlabel("ρ")
plt.ylabel("μ[q(t)]")
plt.show()
# Out:
# Arrival Rate: 0.8
#
# Traffic Intensity: 0.9
# Average Queue Length: 0.5210420841683366
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 0.9188311688311688
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.067948717948718
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 1.2433758586849852
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 3.112391930835735
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 3.5487743871935966
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 7.99583866837388
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 4.172097209720972
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 18.089127130170414
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 19.633792675853517
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.8   # average arrival rate: mean number of enqueues made per unit time, [0.0, 1.0)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.xlabel("ρ")
plt.ylabel("μ[q(t)]")
plt.show()
# Out:
# Arrival Rate: 0.8
#
# Traffic Intensity: 0.9
# Average Queue Length: 1.092184368737475
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 0.8636363636363636
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.1884615384615385
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 1.2011776251226693
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 3.499279538904899
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 2.2546273136568282
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 6.257682458386684
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 4.395319531953195
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 6.150332026562125
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 17.54077081541631
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.7   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.xlabel("ρ")
plt.ylabel("μ[q(t)]")
plt.show()
# Out:
# Arrival Rate: 0.7
#
# Traffic Intensity: 0.9
# Average Queue Length: 2.32064128256513
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 1.3685064935064934
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 2.2858974358974358
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 3.775269872423945
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 3.5072046109510087
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 3.534767383691846
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 5.048335467349552
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 7.188478847884788
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 16.30850468037443
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 55.45194903898078
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.6   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.draw()
plt.pause(0.1)
plt.clf()
# Out:
# Arrival Rate: 0.6
#
# Traffic Intensity: 0.9
# Average Queue Length: 9.715430861723448
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 2.862012987012987
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 10.810256410256411
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 3.52306182531894
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 2.7146974063400577
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 5.3226613306653325
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 12.341549295774648
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 8.331773177317732
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 11.913433074645972
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 20.3367467349347
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.6   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.draw()
plt.pause(0.1)
plt.clf()
# Out:
# Arrival Rate: 0.6
#
# Traffic Intensity: 0.9
# Average Queue Length: 5.565130260521042
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 3.1217532467532467
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.2974358974358975
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 3.0392541707556426
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 4.252881844380403
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 7.674837418709354
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 7.354353393085788
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 13.254185418541855
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 11.046723737899033
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 50.47672953459069
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.3   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.draw()
plt.pause(0.1)
plt.clf()
# Out:
# Arrival Rate: 0.3
#
# Traffic Intensity: 0.9
# Average Queue Length: 1.9559118236472945
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 11.144480519480519
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 4.532051282051282
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 8.424926398429832
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 5.296109510086455
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 4.756378189094547
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 6.3898847631242
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 7.47974797479748
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 25.730858468677493
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 33.08418168363367
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.8   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.draw()
plt.pause(0.1)
plt.clf()
# Out:
# Arrival Rate: 0.8
#
# Traffic Intensity: 0.9
# Average Queue Length: 1.1062124248496994
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 1.0584415584415585
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 1.5269230769230768
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 2.477919528949951
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 1.6945244956772334
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 3.477238619309655
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 5.7554417413572345
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 3.7845184518451847
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 10.08856708536683
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 13.662233244664893
# --------------------------------------------------

# %%
# Simple design of a steady state M/M/1 Queue using Lindley equation.

# Lindley Equation: Computes the queue length with a discrete-time stochastic process.

def perform_bernoulli_trial(p):
    """Performs a single Bernoulli trial with success probability 'p'.
       Function returns a boolean of the trial's success."""
    return random.random() < p


lamb = 0.2   # average arrival rate: mean number of enqueues made per unit time, [0.0, 0.9)
print("Arrival Rate: " + str(lamb))
print()
x = []
y = []

# Simulation

for rho in np.arange(0.9, 1.0, 0.01):
    mu = lamb / rho             # average service rate: mean number of dequeues made per unit time, [0.0, 1.0)
    N = int(10 / ((1 - rho) ** 2))  # sample size
    queue_length = []
    queue = []
    wait = 0
    x.append(rho)
    for t in range(N):          # Simulating N random variables
        
        # Bernoulli trial for the arrival (Enqueueing)
        arrival = perform_bernoulli_trial(lamb)
        if arrival:
            wait += 1
    
        # Dequeueing the M/M/1 Queue
        service = perform_bernoulli_trial(mu)
        if service and wait > 0:
            wait -= 1
    
        # Sampling the data
        queue_length.append(wait)
        if t > N / 2:
            queue.append(wait)

    # Sampling the Queue-Length statistics from the simulation
    print("Traffic Intensity: " + str(rho))
    print("Average Queue Length: " + str(np.average(queue)))
    print("--------------------------------------------------")
    y.append(np.average(queue))

plt.title("Average Queue Length relative to Traffic Intensity")
plt.plot(x, y)
plt.draw()
plt.pause(0.1)
plt.clf()
# Out:
# Arrival Rate: 0.2
#
# Traffic Intensity: 0.9
# Average Queue Length: 3.963927855711423
# --------------------------------------------------
# Traffic Intensity: 0.91
# Average Queue Length: 11.0
# --------------------------------------------------
# Traffic Intensity: 0.92
# Average Queue Length: 23.565384615384616
# --------------------------------------------------
# Traffic Intensity: 0.93
# Average Queue Length: 4.024533856722277
# --------------------------------------------------
# Traffic Intensity: 0.9400000000000001
# Average Queue Length: 8.532420749279538
# --------------------------------------------------
# Traffic Intensity: 0.9500000000000001
# Average Queue Length: 31.02151075537769
# --------------------------------------------------
# Traffic Intensity: 0.9600000000000001
# Average Queue Length: 13.409731113956466
# --------------------------------------------------
# Traffic Intensity: 0.9700000000000001
# Average Queue Length: 14.855985598559856
# --------------------------------------------------
# Traffic Intensity: 0.9800000000000001
# Average Queue Length: 10.367549403952316
# --------------------------------------------------
# Traffic Intensity: 0.9900000000000001
# Average Queue Length: 102.03456069121383
# --------------------------------------------------
